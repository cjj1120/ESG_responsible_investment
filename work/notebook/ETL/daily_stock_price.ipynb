# %%
# Packages
import pynance as pn
import pandas_datareader.data as web
import pandas as pd
import gc 
from datetime import datetime
from datetime import timedelta
import numpy as np

# Directories
transform_path = '../../data/transform'


# del my_array
# del my_object
# gc.collect()

# %% [markdown]
# # Import a list of stocks

# %%
snp_companies = pd.read_csv(f'{transform}/dim_snp_esg_full_16-Jan-2022.csv')

# %%
snp_companies
# Out:
#     ticker             company_name             gics_sector  \
# 0        A     Agilent Technologies             Health Care
# 1      AAL  American Airlines Group             Industrials
# 2      AAP       Advance Auto Parts  Consumer Discretionary
# 3     AAPL                    Apple  Information Technology
# 4     ABBV                   AbbVie             Health Care
# ..     ...                      ...                     ...
# 502    YUM              Yum! Brands  Consumer Discretionary
# 503    ZBH            Zimmer Biomet             Health Care
# 504   ZBRA       Zebra Technologies  Information Technology
# 505   ZION            Zions Bancorp              Financials
# 506    ZTS                   Zoetis             Health Care
#
#                               gics_sub_industry  is_esg
# 0                         Health Care Equipment       1
# 1                                      Airlines       1
# 2                             Automotive Retail       0
# 3    Technology Hardware, Storage & Peripherals       1
# 4                               Pharmaceuticals       1
# ..                                          ...     ...
# 502                                 Restaurants       1
# 503                       Health Care Equipment       0
# 504          Electronic Equipment & Instruments       1
# 505                              Regional Banks       0
# 506                             Pharmaceuticals       0
#
# [507 rows x 5 columns]

# %%
# Filter for ESG companies and the benchmarks
snp_companies_esg = snp_companies[snp_companies['is_esg']==1]
snp_companies_etf = snp_companies[snp_companies['gics_sector']=='ETF']
snp_companies_esg_etf = snp_companies_esg.append(snp_companies_etf)

# Data cleaning
snp_companies_esg_etf['ticker'] = snp_companies_esg_etf['ticker'].str.replace(r'.', '-',regex=True)

# %% [markdown]
# ## Preparing the dataframe to store daily stock prices

# %%
stock_prices = pd.DataFrame()

# Seperated from stock price query because the date range in getting stock price will be converted to incremental loading
# This section is akin to backfilling
start_date = '2021-01-01' 
end_date = '2022-01-14'

# This is done because Yahoo strangely takes your intended query date - 1 day. Hence the base table should match this
base_start_date = (datetime.strptime(start_date, "%Y-%m-%d") - timedelta(days=1)).strftime(format="%Y-%m-%d")
base_end_date = end_date

# This behaves as an index
stock_prices['date'] = pd.Series(pd.date_range(start=base_start_date, end=base_end_date,freq='D'))

# Business Days
biz_date = pd.DataFrame(pd.bdate_range(start=base_start_date, end=base_end_date,freq='B'), columns=['biz_date'])

# Join dates and biz_date to detect weekends or hidden holidays
stock_prices = stock_prices.merge(biz_date,
                                  how='left',
                                  left_on='date',
                                  right_on='biz_date')

# The day of the week with Monday=0, Sunday=6.
stock_prices['day'] = stock_prices['date'].dt.dayofweek

# %% [markdown]
# ## Retrieving Stock Prices

# %%
# Need to add data quality check here to ensure dates do not go out of range

# %%
# Column checker
stock_name_list = snp_companies_esg_etf.ticker.to_list()

print(f"""
We expect an additional {len(stock_name_list)} when the query is done

There are {stock_prices.shape[1]} columns with shape as {stock_prices.shape} in the base dataframe with column names as : {stock_prices.columns.format()}

Therefore, when the data is loaded, there should be {len(stock_name_list) + stock_prices.shape[1]} columns
""")
# Out:
# We expect an additional 313 when the query is done
#
# There are 3 columns with shape as (380, 3) in the base dataframe with column names as : ['date', 'biz_date', 'day']
#
# Therefore, when the data is loaded, there should be 316 columns

# %%
count = 1
error_tickers = []
for stock in stock_name_list:
    try:
        temp_stock_info_df = pd.DataFrame()

        print(f'Processing {stock}')
        print(f'Stock {count} of {len(stock_name_list)}')

        # temp_stock_info_df = (pd
        #                       .DataFrame(
        #                           pn.data.get(stock, base_start_date, base_end_date).loc[:,'Close'])
        #                       .rename({'Close':f'{stock}'},axis=1)
        #                      )
        
        temp_stock_info_df = (pd.DataFrame((web.DataReader(stock, 'yahoo', start=start_date, end=end_date)
                                               .loc[:,'Close']))
                                .rename({'Close':f'{stock}'},axis=1))

        print(f'Successfully processed {stock} at {datetime.today()}!')

        stock_prices = (stock_prices.merge(temp_stock_info_df, 
                                           how='left', 
                                           left_on='date', 
                                           right_on='Date'))

        print(f'DataFrame size is {stock_prices.shape}.\n')

        count += 1

        # Reduce RAM consumption
        del temp_stock_info_df
        gc.collect()
    
    except KeyError:
        error_tickers.append(stock)
        print(f'This ticker {stock} is not found.\n')
        continue
# Out:
# Processing A
# Stock 1 of 313
# Successfully processed A at 2022-01-16 14:52:20.181128!
# DataFrame size is (380, 4).
#
# Processing AAL
# Stock 2 of 313
# Successfully processed AAL at 2022-01-16 14:52:21.634614!
# DataFrame size is (380, 5).
#
# Processing AAPL
# Stock 3 of 313
# Successfully processed AAPL at 2022-01-16 14:52:22.657441!
# DataFrame size is (380, 6).
#
# Processing ABBV
# Stock 4 of 313
# Successfully processed ABBV at 2022-01-16 14:52:23.575415!
# DataFrame size is (380, 7).
#
# Processing ABC
# Stock 5 of 313
# Successfully processed ABC at 2022-01-16 14:52:24.497356!
# DataFrame size is (380, 8).
#
# Processing ABT
# Stock 6 of 313
# Successfully processed ABT at 2022-01-16 14:52:25.583848!
# DataFrame size is (380, 9).
#
# Processing ACN
# Stock 7 of 313
# Successfully processed ACN at 2022-01-16 14:52:26.958393!
# DataFrame size is (380, 10).
#
# Processing ADBE
# Stock 8 of 313
# Successfully processed ADBE at 2022-01-16 14:52:27.882624!
# DataFrame size is (380, 11).
#
# Processing ADI
# Stock 9 of 313
# Successfully processed ADI at 2022-01-16 14:52:28.722201!
# DataFrame size is (380, 12).
#
# Processing ADM
# Stock 10 of 313
# Successfully processed ADM at 2022-01-16 14:52:29.546814!
# DataFrame size is (380, 13).
#
# Processing ADSK
# Stock 11 of 313
# Successfully processed ADSK at 2022-01-16 14:52:30.324572!
# DataFrame size is (380, 14).
#
# Processing AFL
# Stock 12 of 313
# Successfully processed AFL at 2022-01-16 14:52:31.364614!
# DataFrame size is (380, 15).
#
# Processing AIZ
# Stock 13 of 313
# Successfully processed AIZ at 2022-01-16 14:52:32.353183!
# DataFrame size is (380, 16).
#
# Processing AJG
# Stock 14 of 313
# Successfully processed AJG at 2022-01-16 14:52:33.322873!
# DataFrame size is (380, 17).
#
# Processing AKAM
# Stock 15 of 313
# Successfully processed AKAM at 2022-01-16 14:52:34.384665!
# DataFrame size is (380, 18).
#
# Processing ALB
# Stock 16 of 313
# Successfully processed ALB at 2022-01-16 14:52:35.361754!
# DataFrame size is (380, 19).
#
# Processing ALK
# Stock 17 of 313
# Successfully processed ALK at 2022-01-16 14:52:36.641121!
# DataFrame size is (380, 20).
#
# Processing ALL
# Stock 18 of 313
# Successfully processed ALL at 2022-01-16 14:52:37.618695!
# DataFrame size is (380, 21).
#
# Processing AMAT
# Stock 19 of 313
# Successfully processed AMAT at 2022-01-16 14:52:38.752677!
# DataFrame size is (380, 22).
#
# Processing AMD
# Stock 20 of 313
# Successfully processed AMD at 2022-01-16 14:52:39.767971!
# DataFrame size is (380, 23).
#
# Processing AME
# Stock 21 of 313
# Successfully processed AME at 2022-01-16 14:52:40.713264!
# DataFrame size is (380, 24).
#
# Processing AMGN
# Stock 22 of 313
# Successfully processed AMGN at 2022-01-16 14:52:41.515228!
# DataFrame size is (380, 25).
#
# Processing AMP
# Stock 23 of 313
# Successfully processed AMP at 2022-01-16 14:52:42.517145!
# DataFrame size is (380, 26).
#
# Processing AMT
# Stock 24 of 313
# Successfully processed AMT at 2022-01-16 14:52:43.534970!
# DataFrame size is (380, 27).
#
# Processing AMZN
# Stock 25 of 313
# Successfully processed AMZN at 2022-01-16 14:52:44.622004!
# DataFrame size is (380, 28).
#
# Processing ANET
# Stock 26 of 313
# Successfully processed ANET at 2022-01-16 14:52:45.690097!
# DataFrame size is (380, 29).
#
# Processing ANSS
# Stock 27 of 313
# Successfully processed ANSS at 2022-01-16 14:52:46.741390!
# DataFrame size is (380, 30).
#
# Processing ANTM
# Stock 28 of 313
# Successfully processed ANTM at 2022-01-16 14:52:47.665604!
# DataFrame size is (380, 31).
#
# Processing APA
# Stock 29 of 313
# Successfully processed APA at 2022-01-16 14:52:48.678214!
# DataFrame size is (380, 32).
#
# Processing APD
# Stock 30 of 313
# Successfully processed APD at 2022-01-16 14:52:50.318752!
# DataFrame size is (380, 33).
#
# Processing APH
# Stock 31 of 313
# Successfully processed APH at 2022-01-16 14:52:51.332010!
# DataFrame size is (380, 34).
#
# Processing APTV
# Stock 32 of 313
# Successfully processed APTV at 2022-01-16 14:52:52.284734!
# DataFrame size is (380, 35).
#
# Processing ATVI
# Stock 33 of 313
# Successfully processed ATVI at 2022-01-16 14:52:53.152153!
# DataFrame size is (380, 36).
#
# Processing AVB
# Stock 34 of 313
# Successfully processed AVB at 2022-01-16 14:52:54.098127!
# DataFrame size is (380, 37).
#
# Processing AWK
# Stock 35 of 313
# Successfully processed AWK at 2022-01-16 14:52:55.315752!
# DataFrame size is (380, 38).
#
# Processing AXP
# Stock 36 of 313
# Successfully processed AXP at 2022-01-16 14:52:56.374973!
# DataFrame size is (380, 39).
#
# Processing BAC
# Stock 37 of 313
# Successfully processed BAC at 2022-01-16 14:52:57.378649!
# DataFrame size is (380, 40).
#
# Processing BAX
# Stock 38 of 313
# Successfully processed BAX at 2022-01-16 14:52:58.494311!
# DataFrame size is (380, 41).
#
# Processing BBY
# Stock 39 of 313
# Successfully processed BBY at 2022-01-16 14:52:59.606156!
# DataFrame size is (380, 42).
#
# Processing BDX
# Stock 40 of 313
# Successfully processed BDX at 2022-01-16 14:53:00.742954!
# DataFrame size is (380, 43).
#
# Processing BEN
# Stock 41 of 313
# Successfully processed BEN at 2022-01-16 14:53:01.887332!
# DataFrame size is (380, 44).
#
# Processing BF-B
# Stock 42 of 313
# Successfully processed BF-B at 2022-01-16 14:53:02.899960!
# DataFrame size is (380, 45).
#
# Processing BIIB
# Stock 43 of 313
# Successfully processed BIIB at 2022-01-16 14:53:03.840328!
# DataFrame size is (380, 46).
#
# Processing BIO
# Stock 44 of 313
# Successfully processed BIO at 2022-01-16 14:53:04.883283!
# DataFrame size is (380, 47).
#
# Processing BK
# Stock 45 of 313
# Successfully processed BK at 2022-01-16 14:53:05.892887!
# DataFrame size is (380, 48).
#
# Processing BKNG
# Stock 46 of 313
# Successfully processed BKNG at 2022-01-16 14:53:07.005844!
# DataFrame size is (380, 49).
#
# Processing BLK
# Stock 47 of 313
# Successfully processed BLK at 2022-01-16 14:53:08.026090!
# DataFrame size is (380, 50).
#
# Processing BLL
# Stock 48 of 313
# Successfully processed BLL at 2022-01-16 14:53:09.056666!
# DataFrame size is (380, 51).
#
# Processing BMY
# Stock 49 of 313
# Successfully processed BMY at 2022-01-16 14:53:10.272492!
# DataFrame size is (380, 52).
#
# Processing BSX
# Stock 50 of 313
# Successfully processed BSX at 2022-01-16 14:53:12.179449!
# DataFrame size is (380, 53).
#
# Processing BWA
# Stock 51 of 313
# Successfully processed BWA at 2022-01-16 14:53:14.046016!
# DataFrame size is (380, 54).
#
# Processing BXP
# Stock 52 of 313
# Successfully processed BXP at 2022-01-16 14:53:16.088373!
# DataFrame size is (380, 55).
#
# Processing C
# Stock 53 of 313
# Successfully processed C at 2022-01-16 14:53:18.234375!
# DataFrame size is (380, 56).
#
# Processing CAG
# Stock 54 of 313
# Successfully processed CAG at 2022-01-16 14:53:20.083611!
# DataFrame size is (380, 57).
#
# Processing CAH
# Stock 55 of 313
# Successfully processed CAH at 2022-01-16 14:53:22.126732!
# DataFrame size is (380, 58).
#
# Processing CAT
# Stock 56 of 313
# Successfully processed CAT at 2022-01-16 14:53:24.276153!
# DataFrame size is (380, 59).
#
# Processing CB
# Stock 57 of 313
# Successfully processed CB at 2022-01-16 14:53:26.121462!
# DataFrame size is (380, 60).
#
# Processing CBOE
# Stock 58 of 313
# Successfully processed CBOE at 2022-01-16 14:53:28.163528!
# DataFrame size is (380, 61).
#
# Processing CBRE
# Stock 59 of 313
# Successfully processed CBRE at 2022-01-16 14:53:30.319605!
# DataFrame size is (380, 62).
#
# Processing CF
# Stock 60 of 313
# Successfully processed CF at 2022-01-16 14:53:32.165639!
# DataFrame size is (380, 63).
#
# Processing CHTR
# Stock 61 of 313
# Successfully processed CHTR at 2022-01-16 14:53:34.097272!
# DataFrame size is (380, 64).
#
# Processing CI
# Stock 62 of 313
# Successfully processed CI at 2022-01-16 14:53:35.934980!
# DataFrame size is (380, 65).
#
# Processing CL
# Stock 63 of 313
# Successfully processed CL at 2022-01-16 14:53:37.885529!
# DataFrame size is (380, 66).
#
# Processing CMA
# Stock 64 of 313
# Successfully processed CMA at 2022-01-16 14:53:39.741320!
# DataFrame size is (380, 67).
#
# Processing CMCSA
# Stock 65 of 313
# Successfully processed CMCSA at 2022-01-16 14:53:41.789330!
# DataFrame size is (380, 68).
#
# Processing CME
# Stock 66 of 313
# Successfully processed CME at 2022-01-16 14:53:43.574266!
# DataFrame size is (380, 69).
#
# Processing CMI
# Stock 67 of 313
# Successfully processed CMI at 2022-01-16 14:53:45.364605!
# DataFrame size is (380, 70).
#
# Processing COF
# Stock 68 of 313
# Successfully processed COF at 2022-01-16 14:53:47.215791!
# DataFrame size is (380, 71).
#
# Processing COP
# Stock 69 of 313
# Successfully processed COP at 2022-01-16 14:53:49.263547!
# DataFrame size is (380, 72).
#
# Processing CPB
# Stock 70 of 313
# Successfully processed CPB at 2022-01-16 14:53:50.976874!
# DataFrame size is (380, 73).
#
# Processing CRM
# Stock 71 of 313
# Successfully processed CRM at 2022-01-16 14:53:52.851286!
# DataFrame size is (380, 74).
#
# Processing CSCO
# Stock 72 of 313
# Successfully processed CSCO at 2022-01-16 14:53:55.049613!
# DataFrame size is (380, 75).
#
# Processing CSX
# Stock 73 of 313
# Successfully processed CSX at 2022-01-16 14:53:56.844699!
# DataFrame size is (380, 76).
#
# Processing CTAS
# Stock 74 of 313
# Successfully processed CTAS at 2022-01-16 14:53:58.672320!
# DataFrame size is (380, 77).
#
# Processing CTVA
# Stock 75 of 313
# Successfully processed CTVA at 2022-01-16 14:54:00.737992!
# DataFrame size is (380, 78).
#
# Processing CVS
# Stock 76 of 313
# Successfully processed CVS at 2022-01-16 14:54:02.988662!
# DataFrame size is (380, 79).
#
# Processing CVX
# Stock 77 of 313
# Successfully processed CVX at 2022-01-16 14:54:05.034513!
# DataFrame size is (380, 80).
#
# Processing DAL
# Stock 78 of 313
# Successfully processed DAL at 2022-01-16 14:54:06.873399!
# DataFrame size is (380, 81).
#
# Processing DE
# Stock 79 of 313
# Successfully processed DE at 2022-01-16 14:54:08.925168!
# DataFrame size is (380, 82).
#
# Processing DFS
# Stock 80 of 313
# Successfully processed DFS at 2022-01-16 14:54:11.610465!
# DataFrame size is (380, 83).
#
# Processing DGX
# Stock 81 of 313
# Successfully processed DGX at 2022-01-16 14:54:12.533225!
# DataFrame size is (380, 84).
#
# Processing DHR
# Stock 82 of 313
# Successfully processed DHR at 2022-01-16 14:54:13.879945!
# DataFrame size is (380, 85).
#
# Processing DIS
# Stock 83 of 313
# Successfully processed DIS at 2022-01-16 14:54:14.808981!
# DataFrame size is (380, 86).
#
# Processing DISCA
# Stock 84 of 313
# Successfully processed DISCA at 2022-01-16 14:54:16.449465!
# DataFrame size is (380, 87).
#
# Processing DISCK
# Stock 85 of 313
# Successfully processed DISCK at 2022-01-16 14:54:17.464121!
# DataFrame size is (380, 88).
#
# Processing DLR
# Stock 86 of 313
# Successfully processed DLR at 2022-01-16 14:54:18.483121!
# DataFrame size is (380, 89).
#
# Processing DLTR
# Stock 87 of 313
# Successfully processed DLTR at 2022-01-16 14:54:19.502646!
# DataFrame size is (380, 90).
#
# Processing DOV
# Stock 88 of 313
# Successfully processed DOV at 2022-01-16 14:54:20.538578!
# DataFrame size is (380, 91).
#
# Processing DOW
# Stock 89 of 313
# Successfully processed DOW at 2022-01-16 14:54:21.657067!
# DataFrame size is (380, 92).
#
# Processing DRE
# Stock 90 of 313
# Successfully processed DRE at 2022-01-16 14:54:22.814240!
# DataFrame size is (380, 93).
#
# Processing DVA
# Stock 91 of 313
# Successfully processed DVA at 2022-01-16 14:54:23.849693!
# DataFrame size is (380, 94).
#
# Processing DVN
# Stock 92 of 313
# Successfully processed DVN at 2022-01-16 14:54:24.819444!
# DataFrame size is (380, 95).
#
# Processing DXC
# Stock 93 of 313
# Successfully processed DXC at 2022-01-16 14:54:26.358270!
# DataFrame size is (380, 96).
#
# Processing EA
# Stock 94 of 313
# Successfully processed EA at 2022-01-16 14:54:27.484027!
# DataFrame size is (380, 97).
#
# Processing EBAY
# Stock 95 of 313
# Successfully processed EBAY at 2022-01-16 14:54:28.416891!
# DataFrame size is (380, 98).
#
# Processing ECL
# Stock 96 of 313
# Successfully processed ECL at 2022-01-16 14:54:29.433938!
# DataFrame size is (380, 99).
#
# Processing ED
# Stock 97 of 313
# Successfully processed ED at 2022-01-16 14:54:30.252112!
# DataFrame size is (380, 100).
#
# Processing EIX
# Stock 98 of 313
# Successfully processed EIX at 2022-01-16 14:54:31.379685!
# DataFrame size is (380, 101).
#
# Processing EMN
# Stock 99 of 313
# Successfully processed EMN at 2022-01-16 14:54:32.400292!
# DataFrame size is (380, 102).
#
# Processing EMR
# Stock 100 of 313
# Successfully processed EMR at 2022-01-16 14:54:33.385891!
# DataFrame size is (380, 103).
#
# Processing EQIX
# Stock 101 of 313
# Successfully processed EQIX at 2022-01-16 14:54:34.358277!
# DataFrame size is (380, 104).
#
# Processing EQR
# Stock 102 of 313
# Successfully processed EQR at 2022-01-16 14:54:35.455582!
# DataFrame size is (380, 105).
#
# Processing ES
# Stock 103 of 313
# Successfully processed ES at 2022-01-16 14:54:36.439071!
# DataFrame size is (380, 106).
#
# Processing ESS
# Stock 104 of 313
# Successfully processed ESS at 2022-01-16 14:54:38.034263!
# DataFrame size is (380, 107).
#
# Processing ETN
# Stock 105 of 313
# Successfully processed ETN at 2022-01-16 14:54:39.422129!
# DataFrame size is (380, 108).
#
# Processing ETR
# Stock 106 of 313
# Successfully processed ETR at 2022-01-16 14:54:40.596879!
# DataFrame size is (380, 109).
#
# Processing ETSY
# Stock 107 of 313
# Successfully processed ETSY at 2022-01-16 14:54:41.612532!
# DataFrame size is (380, 110).
#
# Processing EW
# Stock 108 of 313
# Successfully processed EW at 2022-01-16 14:54:42.543463!
# DataFrame size is (380, 111).
#
# Processing EXC
# Stock 109 of 313
# Successfully processed EXC at 2022-01-16 14:54:43.736845!
# DataFrame size is (380, 112).
#
# Processing EXR
# Stock 110 of 313
# Successfully processed EXR at 2022-01-16 14:54:44.675382!
# DataFrame size is (380, 113).
#
# Processing F
# Stock 111 of 313
# Successfully processed F at 2022-01-16 14:54:45.607568!
# DataFrame size is (380, 114).
#
# Processing FAST
# Stock 112 of 313
# Successfully processed FAST at 2022-01-16 14:54:46.687354!
# DataFrame size is (380, 115).
#
# Processing FCX
# Stock 113 of 313
# Successfully processed FCX at 2022-01-16 14:54:47.757547!
# DataFrame size is (380, 116).
#
# Processing FDX
# Stock 114 of 313
# Successfully processed FDX at 2022-01-16 14:54:48.786237!
# DataFrame size is (380, 117).
#
# Processing FE
# Stock 115 of 313
# Successfully processed FE at 2022-01-16 14:54:49.807488!
# DataFrame size is (380, 118).
#
# Processing FITB
# Stock 116 of 313
# Successfully processed FITB at 2022-01-16 14:54:50.830407!
# DataFrame size is (380, 119).
#
# Processing FMC
# Stock 117 of 313
# Successfully processed FMC at 2022-01-16 14:54:51.867663!
# DataFrame size is (380, 120).
#
# Processing FTV
# Stock 118 of 313
# Successfully processed FTV at 2022-01-16 14:54:52.873175!
# DataFrame size is (380, 121).
#
# Processing GE
# Stock 119 of 313
# Successfully processed GE at 2022-01-16 14:54:53.739735!
# DataFrame size is (380, 122).
#
# Processing GILD
# Stock 120 of 313
# Successfully processed GILD at 2022-01-16 14:54:54.718077!
# DataFrame size is (380, 123).
#
# Processing GIS
# Stock 121 of 313
# Successfully processed GIS at 2022-01-16 14:54:55.742864!
# DataFrame size is (380, 124).
#
# Processing GL
# Stock 122 of 313
# Successfully processed GL at 2022-01-16 14:54:57.293299!
# DataFrame size is (380, 125).
#
# Processing GLW
# Stock 123 of 313
# Successfully processed GLW at 2022-01-16 14:54:58.300236!
# DataFrame size is (380, 126).
#
# Processing GM
# Stock 124 of 313
# Successfully processed GM at 2022-01-16 14:54:59.335067!
# DataFrame size is (380, 127).
#
# Processing GOOG
# Stock 125 of 313
# Successfully processed GOOG at 2022-01-16 14:55:00.151406!
# DataFrame size is (380, 128).
#
# Processing GOOGL
# Stock 126 of 313
# Successfully processed GOOGL at 2022-01-16 14:55:01.170251!
# DataFrame size is (380, 129).
#
# Processing GPS
# Stock 127 of 313
# Successfully processed GPS at 2022-01-16 14:55:02.088747!
# DataFrame size is (380, 130).
#
# Processing GS
# Stock 128 of 313
# Successfully processed GS at 2022-01-16 14:55:03.058036!
# DataFrame size is (380, 131).
#
# Processing GWW
# Stock 129 of 313
# Successfully processed GWW at 2022-01-16 14:55:04.462208!
# DataFrame size is (380, 132).
#
# Processing HAL
# Stock 130 of 313
# Successfully processed HAL at 2022-01-16 14:55:05.475672!
# DataFrame size is (380, 133).
#
# Processing HAS
# Stock 131 of 313
# Successfully processed HAS at 2022-01-16 14:55:06.458328!
# DataFrame size is (380, 134).
#
# Processing HD
# Stock 132 of 313
# Successfully processed HD at 2022-01-16 14:55:07.362512!
# DataFrame size is (380, 135).
#
# Processing HES
# Stock 133 of 313
# Successfully processed HES at 2022-01-16 14:55:08.861715!
# DataFrame size is (380, 136).
#
# Processing HIG
# Stock 134 of 313
# Successfully processed HIG at 2022-01-16 14:55:10.088898!
# DataFrame size is (380, 137).
#
# Processing HLT
# Stock 135 of 313
# Successfully processed HLT at 2022-01-16 14:55:11.116973!
# DataFrame size is (380, 138).
#
# Processing HOLX
# Stock 136 of 313
# Successfully processed HOLX at 2022-01-16 14:55:12.662012!
# DataFrame size is (380, 139).
#
# Processing HPE
# Stock 137 of 313
# Successfully processed HPE at 2022-01-16 14:55:13.897811!
# DataFrame size is (380, 140).
#
# Processing HPQ
# Stock 138 of 313
# Successfully processed HPQ at 2022-01-16 14:55:14.896274!
# DataFrame size is (380, 141).
#
# Processing HRL
# Stock 139 of 313
# Successfully processed HRL at 2022-01-16 14:55:15.930390!
# DataFrame size is (380, 142).
#
# Processing HSIC
# Stock 140 of 313
# Successfully processed HSIC at 2022-01-16 14:55:16.997929!
# DataFrame size is (380, 143).
#
# Processing HST
# Stock 141 of 313
# Successfully processed HST at 2022-01-16 14:55:18.080607!
# DataFrame size is (380, 144).
#
# Processing HSY
# Stock 142 of 313
# Successfully processed HSY at 2022-01-16 14:55:19.115274!
# DataFrame size is (380, 145).
#
# Processing HUM
# Stock 143 of 313
# Successfully processed HUM at 2022-01-16 14:55:20.134662!
# DataFrame size is (380, 146).
#
# Processing HWM
# Stock 144 of 313
# Successfully processed HWM at 2022-01-16 14:55:21.144112!
# DataFrame size is (380, 147).
#
# Processing ICE
# Stock 145 of 313
# Successfully processed ICE at 2022-01-16 14:55:22.134779!
# DataFrame size is (380, 148).
#
# Processing IDXX
# Stock 146 of 313
# Successfully processed IDXX at 2022-01-16 14:55:23.113711!
# DataFrame size is (380, 149).
#
# Processing IEX
# Stock 147 of 313
# Successfully processed IEX at 2022-01-16 14:55:24.126559!
# DataFrame size is (380, 150).
#
# Processing IFF
# Stock 148 of 313
# Successfully processed IFF at 2022-01-16 14:55:25.154600!
# DataFrame size is (380, 151).
#
# Processing ILMN
# Stock 149 of 313
# Successfully processed ILMN at 2022-01-16 14:55:26.161300!
# DataFrame size is (380, 152).
#
# Processing INCY
# Stock 150 of 313
# Successfully processed INCY at 2022-01-16 14:55:27.495656!
# DataFrame size is (380, 153).
#
# Processing INFO
# Stock 151 of 313
# Successfully processed INFO at 2022-01-16 14:55:28.511110!
# DataFrame size is (380, 154).
#
# Processing INTC
# Stock 152 of 313
# Successfully processed INTC at 2022-01-16 14:55:29.565379!
# DataFrame size is (380, 155).
#
# Processing INTU
# Stock 153 of 313
# Successfully processed INTU at 2022-01-16 14:55:30.949646!
# DataFrame size is (380, 156).
#
# Processing IP
# Stock 154 of 313
# Successfully processed IP at 2022-01-16 14:55:31.704063!
# DataFrame size is (380, 157).
#
# Processing IPG
# Stock 155 of 313
# Successfully processed IPG at 2022-01-16 14:55:32.731788!
# DataFrame size is (380, 158).
#
# Processing IR
# Stock 156 of 313
# Successfully processed IR at 2022-01-16 14:55:33.748650!
# DataFrame size is (380, 159).
#
# Processing IRM
# Stock 157 of 313
# Successfully processed IRM at 2022-01-16 14:55:35.486853!
# DataFrame size is (380, 160).
#
# Processing ITW
# Stock 158 of 313
# Successfully processed ITW at 2022-01-16 14:55:36.440664!
# DataFrame size is (380, 161).
#
# Processing IVZ
# Stock 159 of 313
# Successfully processed IVZ at 2022-01-16 14:55:37.537292!
# DataFrame size is (380, 162).
#
# Processing JCI
# Stock 160 of 313
# Successfully processed JCI at 2022-01-16 14:55:38.575064!
# DataFrame size is (380, 163).
#
# Processing JNPR
# Stock 161 of 313
# Successfully processed JNPR at 2022-01-16 14:55:39.692898!
# DataFrame size is (380, 164).
#
# Processing JPM
# Stock 162 of 313
# Successfully processed JPM at 2022-01-16 14:55:40.682964!
# DataFrame size is (380, 165).
#
# Processing K
# Stock 163 of 313
# Successfully processed K at 2022-01-16 14:55:41.660503!
# DataFrame size is (380, 166).
#
# Processing KEY
# Stock 164 of 313
# Successfully processed KEY at 2022-01-16 14:55:42.565036!
# DataFrame size is (380, 167).
#
# Processing KEYS
# Stock 165 of 313
# Successfully processed KEYS at 2022-01-16 14:55:43.429702!
# DataFrame size is (380, 168).
#
# Processing KHC
# Stock 166 of 313
# Successfully processed KHC at 2022-01-16 14:55:44.490328!
# DataFrame size is (380, 169).
#
# Processing KIM
# Stock 167 of 313
# Successfully processed KIM at 2022-01-16 14:55:45.217212!
# DataFrame size is (380, 170).
#
# Processing KLAC
# Stock 168 of 313
# Successfully processed KLAC at 2022-01-16 14:55:46.163435!
# DataFrame size is (380, 171).
#
# Processing KMI
# Stock 169 of 313
# Successfully processed KMI at 2022-01-16 14:55:47.569686!
# DataFrame size is (380, 172).
#
# Processing KMX
# Stock 170 of 313
# Successfully processed KMX at 2022-01-16 14:55:48.593783!
# DataFrame size is (380, 173).
#
# Processing KO
# Stock 171 of 313
# Successfully processed KO at 2022-01-16 14:55:49.614759!
# DataFrame size is (380, 174).
#
# Processing KR
# Stock 172 of 313
# Successfully processed KR at 2022-01-16 14:55:51.147181!
# DataFrame size is (380, 175).
#
# Processing LDOS
# Stock 173 of 313
# Successfully processed LDOS at 2022-01-16 14:55:52.577991!
# DataFrame size is (380, 176).
#
# Processing LH
# Stock 174 of 313
# Successfully processed LH at 2022-01-16 14:55:53.605841!
# DataFrame size is (380, 177).
#
# Processing LHX
# Stock 175 of 313
# Successfully processed LHX at 2022-01-16 14:55:54.625532!
# DataFrame size is (380, 178).
#
# Processing LIN
# Stock 176 of 313
# Successfully processed LIN at 2022-01-16 14:55:55.695524!
# DataFrame size is (380, 179).
#
# Processing LLY
# Stock 177 of 313
# Successfully processed LLY at 2022-01-16 14:55:56.674204!
# DataFrame size is (380, 180).
#
# Processing LNC
# Stock 178 of 313
# Successfully processed LNC at 2022-01-16 14:55:57.702390!
# DataFrame size is (380, 181).
#
# Processing LOW
# Stock 179 of 313
# Successfully processed LOW at 2022-01-16 14:55:58.925494!
# DataFrame size is (380, 182).
#
# Processing LRCX
# Stock 180 of 313
# Successfully processed LRCX at 2022-01-16 14:56:00.481167!
# DataFrame size is (380, 183).
#
# Processing LVS
# Stock 181 of 313
# Successfully processed LVS at 2022-01-16 14:56:02.630163!
# DataFrame size is (380, 184).
#
# Processing LYB
# Stock 182 of 313
# Successfully processed LYB at 2022-01-16 14:56:04.774560!
# DataFrame size is (380, 185).
#
# Processing LYV
# Stock 183 of 313
# Successfully processed LYV at 2022-01-16 14:56:06.619801!
# DataFrame size is (380, 186).
#
# Processing MA
# Stock 184 of 313
# Successfully processed MA at 2022-01-16 14:56:08.762249!
# DataFrame size is (380, 187).
#
# Processing MAR
# Stock 185 of 313
# Successfully processed MAR at 2022-01-16 14:56:10.888739!
# DataFrame size is (380, 188).
#
# Processing MCD
# Stock 186 of 313
# Successfully processed MCD at 2022-01-16 14:56:13.583535!
# DataFrame size is (380, 189).
#
# Processing MCK
# Stock 187 of 313
# Successfully processed MCK at 2022-01-16 14:56:15.939893!
# DataFrame size is (380, 190).
#
# Processing MCO
# Stock 188 of 313
# Successfully processed MCO at 2022-01-16 14:56:18.190565!
# DataFrame size is (380, 191).
#
# Processing MDLZ
# Stock 189 of 313
# Successfully processed MDLZ at 2022-01-16 14:56:20.254994!
# DataFrame size is (380, 192).
#
# Processing MDT
# Stock 190 of 313
# Successfully processed MDT at 2022-01-16 14:56:22.195075!
# DataFrame size is (380, 193).
#
# Processing MET
# Stock 191 of 313
# Successfully processed MET at 2022-01-16 14:56:24.648069!
# DataFrame size is (380, 194).
#
# Processing MGM
# Stock 192 of 313
# Successfully processed MGM at 2022-01-16 14:56:26.783345!
# DataFrame size is (380, 195).
#
# Processing MKC
# Stock 193 of 313
# Successfully processed MKC at 2022-01-16 14:56:29.400232!
# DataFrame size is (380, 196).
#
# Processing MKTX
# Stock 194 of 313
# Successfully processed MKTX at 2022-01-16 14:56:32.179515!
# DataFrame size is (380, 197).
#
# Processing MLM
# Stock 195 of 313
# Successfully processed MLM at 2022-01-16 14:56:34.678813!
# DataFrame size is (380, 198).
#
# Processing MMC
# Stock 196 of 313
# Successfully processed MMC at 2022-01-16 14:56:37.364253!
# DataFrame size is (380, 199).
#
# Processing MOS
# Stock 197 of 313
# Successfully processed MOS at 2022-01-16 14:56:39.904449!
# DataFrame size is (380, 200).
#
# Processing MPC
# Stock 198 of 313
# Successfully processed MPC at 2022-01-16 14:56:42.451398!
# DataFrame size is (380, 201).
#
# Processing MRK
# Stock 199 of 313
# Successfully processed MRK at 2022-01-16 14:56:44.736132!
# DataFrame size is (380, 202).
#
# Processing MS
# Stock 200 of 313
# Successfully processed MS at 2022-01-16 14:56:47.262056!
# DataFrame size is (380, 203).
#
# Processing MSCI
# Stock 201 of 313
# Successfully processed MSCI at 2022-01-16 14:56:49.723414!
# DataFrame size is (380, 204).
#
# Processing MSFT
# Stock 202 of 313
# Successfully processed MSFT at 2022-01-16 14:56:51.981550!
# DataFrame size is (380, 205).
#
# Processing MSI
# Stock 203 of 313
# Successfully processed MSI at 2022-01-16 14:56:54.448386!
# DataFrame size is (380, 206).
#
# Processing MTD
# Stock 204 of 313
# Successfully processed MTD at 2022-01-16 14:56:56.378407!
# DataFrame size is (380, 207).
#
# Processing MU
# Stock 205 of 313
# Successfully processed MU at 2022-01-16 14:56:58.497032!
# DataFrame size is (380, 208).
#
# Processing NDAQ
# Stock 206 of 313
# Successfully processed NDAQ at 2022-01-16 14:57:00.260646!
# DataFrame size is (380, 209).
#
# Processing NEE
# Stock 207 of 313
# Successfully processed NEE at 2022-01-16 14:57:02.427316!
# DataFrame size is (380, 210).
#
# Processing NEM
# Stock 208 of 313
# Successfully processed NEM at 2022-01-16 14:57:05.092349!
# DataFrame size is (380, 211).
#
# Processing NKE
# Stock 209 of 313
# Successfully processed NKE at 2022-01-16 14:57:07.483328!
# DataFrame size is (380, 212).
#
# Processing NLOK
# Stock 210 of 313
# Successfully processed NLOK at 2022-01-16 14:57:10.411492!
# DataFrame size is (380, 213).
#
# Processing NLSN
# Stock 211 of 313
# Successfully processed NLSN at 2022-01-16 14:57:12.669711!
# DataFrame size is (380, 214).
#
# Processing NSC
# Stock 212 of 313
# Successfully processed NSC at 2022-01-16 14:57:14.931029!
# DataFrame size is (380, 215).
#
# Processing NTRS
# Stock 213 of 313
# Successfully processed NTRS at 2022-01-16 14:57:16.910001!
# DataFrame size is (380, 216).
#
# Processing NVDA
# Stock 214 of 313
# Successfully processed NVDA at 2022-01-16 14:57:18.901714!
# DataFrame size is (380, 217).
#
# Processing NWL
# Stock 215 of 313
# Successfully processed NWL at 2022-01-16 14:57:21.055881!
# DataFrame size is (380, 218).
#
# Processing NWS
# Stock 216 of 313
# Successfully processed NWS at 2022-01-16 14:57:23.328007!
# DataFrame size is (380, 219).
#
# Processing NWSA
# Stock 217 of 313
# Successfully processed NWSA at 2022-01-16 14:57:25.150922!
# DataFrame size is (380, 220).
#
# Processing O
# Stock 218 of 313
# Successfully processed O at 2022-01-16 14:57:27.420581!
# DataFrame size is (380, 221).
#
# Processing OKE
# Stock 219 of 313
# Successfully processed OKE at 2022-01-16 14:57:29.969606!
# DataFrame size is (380, 222).
#
# Processing OMC
# Stock 220 of 313
# Successfully processed OMC at 2022-01-16 14:57:32.289712!
# DataFrame size is (380, 223).
#
# Processing ORCL
# Stock 221 of 313
# Successfully processed ORCL at 2022-01-16 14:57:34.958920!
# DataFrame size is (380, 224).
#
# Processing OXY
# Stock 222 of 313
# Successfully processed OXY at 2022-01-16 14:57:37.765335!
# DataFrame size is (380, 225).
#
# Processing PCAR
# Stock 223 of 313
# Successfully processed PCAR at 2022-01-16 14:57:40.519836!
# DataFrame size is (380, 226).
#
# Processing PEAK
# Stock 224 of 313
# Successfully processed PEAK at 2022-01-16 14:57:42.255081!
# DataFrame size is (380, 227).
#
# Processing PEG
# Stock 225 of 313
# Successfully processed PEG at 2022-01-16 14:57:44.380365!
# DataFrame size is (380, 228).
#
# Processing PEP
# Stock 226 of 313
# Successfully processed PEP at 2022-01-16 14:57:47.373472!
# DataFrame size is (380, 229).
#
# Processing PFE
# Stock 227 of 313
# Successfully processed PFE at 2022-01-16 14:57:50.066903!
# DataFrame size is (380, 230).
#
# Processing PFG
# Stock 228 of 313
# Successfully processed PFG at 2022-01-16 14:57:51.990930!
# DataFrame size is (380, 231).
#
# Processing PG
# Stock 229 of 313
# Successfully processed PG at 2022-01-16 14:57:54.339048!
# DataFrame size is (380, 232).
#
# Processing PGR
# Stock 230 of 313
# Successfully processed PGR at 2022-01-16 14:57:56.655116!
# DataFrame size is (380, 233).
#
# Processing PH
# Stock 231 of 313
# Successfully processed PH at 2022-01-16 14:57:59.254880!
# DataFrame size is (380, 234).
#
# Processing PHM
# Stock 232 of 313
# Successfully processed PHM at 2022-01-16 14:58:01.405110!
# DataFrame size is (380, 235).
#
# Processing PKI
# Stock 233 of 313
# Successfully processed PKI at 2022-01-16 14:58:04.279113!
# DataFrame size is (380, 236).
#
# Processing PLD
# Stock 234 of 313
# Successfully processed PLD at 2022-01-16 14:58:07.334720!
# DataFrame size is (380, 237).
#
# Processing PNC
# Stock 235 of 313
# Successfully processed PNC at 2022-01-16 14:58:09.911129!
# DataFrame size is (380, 238).
#
# Processing PNR
# Stock 236 of 313
# Successfully processed PNR at 2022-01-16 14:58:11.770676!
# DataFrame size is (380, 239).
#
# Processing PPG
# Stock 237 of 313
# Successfully processed PPG at 2022-01-16 14:58:14.317489!
# DataFrame size is (380, 240).
#
# Processing PRU
# Stock 238 of 313
# Successfully processed PRU at 2022-01-16 14:58:16.137496!
# DataFrame size is (380, 241).
#
# Processing PVH
# Stock 239 of 313
# Successfully processed PVH at 2022-01-16 14:58:18.831772!
# DataFrame size is (380, 242).
#
# Processing PXD
# Stock 240 of 313
# Successfully processed PXD at 2022-01-16 14:58:21.388263!
# DataFrame size is (380, 243).
#
# Processing QCOM
# Stock 241 of 313
# Successfully processed QCOM at 2022-01-16 14:58:23.838813!
# DataFrame size is (380, 244).
#
# Processing RCL
# Stock 242 of 313
# Successfully processed RCL at 2022-01-16 14:58:26.196515!
# DataFrame size is (380, 245).
#
# Processing REG
# Stock 243 of 313
# Successfully processed REG at 2022-01-16 14:58:28.336665!
# DataFrame size is (380, 246).
#
# Processing REGN
# Stock 244 of 313
# Successfully processed REGN at 2022-01-16 14:58:30.295703!
# DataFrame size is (380, 247).
#
# Processing RF
# Stock 245 of 313
# Successfully processed RF at 2022-01-16 14:58:32.758637!
# DataFrame size is (380, 248).
#
# Processing RHI
# Stock 246 of 313
# Successfully processed RHI at 2022-01-16 14:58:35.351008!
# DataFrame size is (380, 249).
#
# Processing RJF
# Stock 247 of 313
# Successfully processed RJF at 2022-01-16 14:58:37.976809!
# DataFrame size is (380, 250).
#
# Processing RL
# Stock 248 of 313
# Successfully processed RL at 2022-01-16 14:58:40.080226!
# DataFrame size is (380, 251).
#
# Processing ROK
# Stock 249 of 313
# Successfully processed ROK at 2022-01-16 14:58:41.303457!
# DataFrame size is (380, 252).
#
# Processing ROP
# Stock 250 of 313
# Successfully processed ROP at 2022-01-16 14:58:43.035308!
# DataFrame size is (380, 253).
#
# Processing RSG
# Stock 251 of 313
# Successfully processed RSG at 2022-01-16 14:58:45.844756!
# DataFrame size is (380, 254).
#
# Processing SBUX
# Stock 252 of 313
# Successfully processed SBUX at 2022-01-16 14:58:48.101464!
# DataFrame size is (380, 255).
#
# Processing SCHW
# Stock 253 of 313
# Successfully processed SCHW at 2022-01-16 14:58:50.461205!
# DataFrame size is (380, 256).
#
# Processing SJM
# Stock 254 of 313
# Successfully processed SJM at 2022-01-16 14:58:52.511171!
# DataFrame size is (380, 257).
#
# Processing SLB
# Stock 255 of 313
# Successfully processed SLB at 2022-01-16 14:58:55.383013!
# DataFrame size is (380, 258).
#
# Processing SNA
# Stock 256 of 313
# Successfully processed SNA at 2022-01-16 14:58:57.006644!
# DataFrame size is (380, 259).
#
# Processing SNPE
# Stock 257 of 313
# Successfully processed SNPE at 2022-01-16 14:58:59.159260!
# DataFrame size is (380, 260).
#
# Processing SPG
# Stock 258 of 313
# Successfully processed SPG at 2022-01-16 14:59:01.540075!
# DataFrame size is (380, 261).
#
# Processing SPGI
# Stock 259 of 313
# Successfully processed SPGI at 2022-01-16 14:59:03.462728!
# DataFrame size is (380, 262).
#
# Processing SRE
# Stock 260 of 313
# Successfully processed SRE at 2022-01-16 14:59:06.410099!
# DataFrame size is (380, 263).
#
# Processing STT
# Stock 261 of 313
# Successfully processed STT at 2022-01-16 14:59:09.579960!
# DataFrame size is (380, 264).
#
# Processing STX
# Stock 262 of 313
# Successfully processed STX at 2022-01-16 14:59:12.480324!
# DataFrame size is (380, 265).
#
# Processing STZ
# Stock 263 of 313
# Successfully processed STZ at 2022-01-16 14:59:15.831856!
# DataFrame size is (380, 266).
#
# Processing SWK
# Stock 264 of 313
# Successfully processed SWK at 2022-01-16 14:59:18.892408!
# DataFrame size is (380, 267).
#
# Processing SYF
# Stock 265 of 313
# Successfully processed SYF at 2022-01-16 14:59:21.083786!
# DataFrame size is (380, 268).
#
# Processing SYY
# Stock 266 of 313
# Successfully processed SYY at 2022-01-16 14:59:23.595976!
# DataFrame size is (380, 269).
#
# Processing T
# Stock 267 of 313
# Successfully processed T at 2022-01-16 14:59:25.378780!
# DataFrame size is (380, 270).
#
# Processing TAP
# Stock 268 of 313
# Successfully processed TAP at 2022-01-16 14:59:27.733606!
# DataFrame size is (380, 271).
#
# Processing TDG
# Stock 269 of 313
# Successfully processed TDG at 2022-01-16 14:59:29.578283!
# DataFrame size is (380, 272).
#
# Processing TEL
# Stock 270 of 313
# Successfully processed TEL at 2022-01-16 14:59:31.626027!
# DataFrame size is (380, 273).
#
# Processing TGT
# Stock 271 of 313
# Successfully processed TGT at 2022-01-16 14:59:34.089919!
# DataFrame size is (380, 274).
#
# Processing TJX
# Stock 272 of 313
# Successfully processed TJX at 2022-01-16 14:59:36.858862!
# DataFrame size is (380, 275).
#
# Processing TMO
# Stock 273 of 313
# Successfully processed TMO at 2022-01-16 14:59:39.327048!
# DataFrame size is (380, 276).
#
# Processing TPR
# Stock 274 of 313
# Successfully processed TPR at 2022-01-16 14:59:41.760247!
# DataFrame size is (380, 277).
#
# Processing TRMB
# Stock 275 of 313
# Successfully processed TRMB at 2022-01-16 14:59:43.955284!
# DataFrame size is (380, 278).
#
# Processing TROW
# Stock 276 of 313
# Successfully processed TROW at 2022-01-16 14:59:46.607134!
# DataFrame size is (380, 279).
#
# Processing TRV
# Stock 277 of 313
# Successfully processed TRV at 2022-01-16 14:59:49.030814!
# DataFrame size is (380, 280).
#
# Processing TSLA
# Stock 278 of 313
# Successfully processed TSLA at 2022-01-16 14:59:49.950985!
# DataFrame size is (380, 281).
#
# Processing TSN
# Stock 279 of 313
# Successfully processed TSN at 2022-01-16 14:59:52.634726!
# DataFrame size is (380, 282).
#
# Processing TT
# Stock 280 of 313
# Successfully processed TT at 2022-01-16 14:59:55.079278!
# DataFrame size is (380, 283).
#
# Processing TTWO
# Stock 281 of 313
# Successfully processed TTWO at 2022-01-16 14:59:56.412372!
# DataFrame size is (380, 284).
#
# Processing TXN
# Stock 282 of 313
# Successfully processed TXN at 2022-01-16 14:59:59.274085!
# DataFrame size is (380, 285).
#
# Processing UA
# Stock 283 of 313
# Successfully processed UA at 2022-01-16 15:00:01.249006!
# DataFrame size is (380, 286).
#
# Processing UAA
# Stock 284 of 313
# Successfully processed UAA at 2022-01-16 15:00:02.869572!
# DataFrame size is (380, 287).
#
# Processing UNH
# Stock 285 of 313
# Successfully processed UNH at 2022-01-16 15:00:04.908441!
# DataFrame size is (380, 288).
#
# Processing UNP
# Stock 286 of 313
# Successfully processed UNP at 2022-01-16 15:00:07.364606!
# DataFrame size is (380, 289).
#
# Processing UPS
# Stock 287 of 313
# Successfully processed UPS at 2022-01-16 15:00:08.700594!
# DataFrame size is (380, 290).
#
# Processing URI
# Stock 288 of 313
# Successfully processed URI at 2022-01-16 15:00:11.259683!
# DataFrame size is (380, 291).
#
# Processing V
# Stock 289 of 313
# Successfully processed V at 2022-01-16 15:00:13.830182!
# DataFrame size is (380, 292).
#
# Processing VFC
# Stock 290 of 313
# Successfully processed VFC at 2022-01-16 15:00:16.287633!
# DataFrame size is (380, 293).
#
# Processing VNO
# Stock 291 of 313
# Successfully processed VNO at 2022-01-16 15:00:18.365271!
# DataFrame size is (380, 294).
#
# Processing VRSK
# Stock 292 of 313
# Successfully processed VRSK at 2022-01-16 15:00:20.531439!
# DataFrame size is (380, 295).
#
# Processing VRTX
# Stock 293 of 313
# Successfully processed VRTX at 2022-01-16 15:00:22.521420!
# DataFrame size is (380, 296).
#
# Processing VTR
# Stock 294 of 313
# Successfully processed VTR at 2022-01-16 15:00:24.366919!
# DataFrame size is (380, 297).
#
# Processing VTRS
# Stock 295 of 313
# Successfully processed VTRS at 2022-01-16 15:00:26.918733!
# DataFrame size is (380, 298).
#
# Processing VZ
# Stock 296 of 313
# Successfully processed VZ at 2022-01-16 15:00:29.581715!
# DataFrame size is (380, 299).
#
# Processing WAB
# Stock 297 of 313
# Successfully processed WAB at 2022-01-16 15:00:31.386246!
# DataFrame size is (380, 300).
#
# Processing WAT
# Stock 298 of 313
# Successfully processed WAT at 2022-01-16 15:00:34.097650!
# DataFrame size is (380, 301).
#
# Processing WBA
# Stock 299 of 313
# Successfully processed WBA at 2022-01-16 15:00:36.745295!
# DataFrame size is (380, 302).
#
# Processing WELL
# Stock 300 of 313
# Successfully processed WELL at 2022-01-16 15:00:39.221183!
# DataFrame size is (380, 303).
#
# Processing WHR
# Stock 301 of 313
# Successfully processed WHR at 2022-01-16 15:00:41.138040!
# DataFrame size is (380, 304).
#
# Processing WM
# Stock 302 of 313
# Successfully processed WM at 2022-01-16 15:00:42.965821!
# DataFrame size is (380, 305).
#
# Processing WMB
# Stock 303 of 313
# Successfully processed WMB at 2022-01-16 15:00:45.146760!
# DataFrame size is (380, 306).
#
# Processing WMT
# Stock 304 of 313
# Successfully processed WMT at 2022-01-16 15:00:47.498600!
# DataFrame size is (380, 307).
#
# Processing WRK
# Stock 305 of 313
# Successfully processed WRK at 2022-01-16 15:00:49.449608!
# DataFrame size is (380, 308).
#
# Processing WST
# Stock 306 of 313
# Successfully processed WST at 2022-01-16 15:00:52.101824!
# DataFrame size is (380, 309).
#
# Processing WY
# Stock 307 of 313
# Successfully processed WY at 2022-01-16 15:00:54.892578!
# DataFrame size is (380, 310).
#
# Processing XOM
# Stock 308 of 313
# Successfully processed XOM at 2022-01-16 15:00:56.486266!
# DataFrame size is (380, 311).
#
# Processing XYL
# Stock 309 of 313
# Successfully processed XYL at 2022-01-16 15:00:58.538849!
# DataFrame size is (380, 312).
#
# Processing YUM
# Stock 310 of 313
# Successfully processed YUM at 2022-01-16 15:01:00.914102!
# DataFrame size is (380, 313).
#
# Processing ZBRA
# Stock 311 of 313
# Successfully processed ZBRA at 2022-01-16 15:01:02.672093!
# DataFrame size is (380, 314).
#
# Processing SNPE
# Stock 312 of 313
# Successfully processed SNPE at 2022-01-16 15:01:05.011716!
# DataFrame size is (380, 315).
#
# Processing SPY
# Stock 313 of 313
# Successfully processed SPY at 2022-01-16 15:01:07.467998!
# DataFrame size is (380, 316).

# %%
# my notes
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html

# In [39]: import pandas_datareader.data as web

# In [40]: import pandas as pd

# In [41]: import datetime as dt

# In [42]: df = web.DataReader('GE', 'yahoo', start='2019-09-10', end='2019-10-09')

## Pynance
# pn.data.get('AAPL', base_start_date, base_end_date)

# %%
stock_prices.to_csv(f"{transform_path}/fact_esg_stock_prices.csv",index=False)

# %%
print(error_tickers)
# Out:
# []
