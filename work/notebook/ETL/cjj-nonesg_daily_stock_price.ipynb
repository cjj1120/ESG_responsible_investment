# %%
# Packages
import pynance as pn
import pandas_datareader.data as web
import pandas as pd
import gc 
from datetime import datetime
from datetime import timedelta
import numpy as np

# Directories
transform = '../../data/transform'


# del my_array
# del my_object
# gc.collect()

# %% [markdown]
# # Import a list of stocks

# %%
snp_companies = pd.read_csv(f'{transform}/dim_snp_esg_full_16-Jan-2022.csv')

# %%
snp_companies
# Out:
#     ticker             company_name             gics_sector  \
# 0        A     Agilent Technologies             Health Care
# 1      AAL  American Airlines Group             Industrials
# 2      AAP       Advance Auto Parts  Consumer Discretionary
# 3     AAPL                    Apple  Information Technology
# 4     ABBV                   AbbVie             Health Care
# ..     ...                      ...                     ...
# 502    YUM              Yum! Brands  Consumer Discretionary
# 503    ZBH            Zimmer Biomet             Health Care
# 504   ZBRA       Zebra Technologies  Information Technology
# 505   ZION            Zions Bancorp              Financials
# 506    ZTS                   Zoetis             Health Care
#
#                               gics_sub_industry  is_esg
# 0                         Health Care Equipment       1
# 1                                      Airlines       1
# 2                             Automotive Retail       0
# 3    Technology Hardware, Storage & Peripherals       1
# 4                               Pharmaceuticals       1
# ..                                          ...     ...
# 502                                 Restaurants       1
# 503                       Health Care Equipment       0
# 504          Electronic Equipment & Instruments       1
# 505                              Regional Banks       0
# 506                             Pharmaceuticals       0
#
# [507 rows x 5 columns]

# %%
# Filter for ESG companies and the benchmarks
snp_companies_esg = snp_companies[snp_companies['is_esg']==0]
snp_companies_etf = snp_companies[snp_companies['gics_sector']=='ETF']
snp_companies_esg_etf = snp_companies_esg.append(snp_companies_etf)

# Data cleaning
snp_companies_esg_etf['ticker'] = snp_companies_esg_etf['ticker'].str.replace(r'.', '-',regex=True)
snp_companies_esg_etf = snp_companies_esg_etf.drop_duplicates()

# %% [markdown]
# ## Preparing the dataframe to store daily stock prices

# %%
stock_prices = pd.DataFrame()

# Seperated from stock price query because the date range in getting stock price will be converted to incremental loading
# This section is akin to backfilling
start_date = '2021-01-01' 
end_date = '2022-01-14'

# This is done because Yahoo strangely takes your intended query date - 1 day. Hence the base table should match this
base_start_date = (datetime.strptime(start_date, "%Y-%m-%d") - timedelta(days=1)).strftime(format="%Y-%m-%d")
base_end_date = end_date

# This behaves as an index
stock_prices['date'] = pd.Series(pd.date_range(start=base_start_date, end=base_end_date,freq='D'))

# Business Days
biz_date = pd.DataFrame(pd.bdate_range(start=base_start_date, end=base_end_date,freq='B'), columns=['biz_date'])

# Join dates and biz_date to detect weekends or hidden holidays
stock_prices = stock_prices.merge(biz_date,
                                  how='left',
                                  left_on='date',
                                  right_on='biz_date')

# The day of the week with Monday=0, Sunday=6.
stock_prices['day'] = stock_prices['date'].dt.dayofweek

# %% [markdown]
# ## Retrieving Stock Prices

# %%
# Need to add data quality check here to ensure dates do not go out of range

# %%
# Column checker
stock_name_list = snp_companies_esg_etf.ticker.to_list()

print(f"""
We expect an additional {len(stock_name_list)} columns when the query is done

There are {stock_prices.shape[1]} columns with shape as {stock_prices.shape} in the base dataframe with column names as : {stock_prices.columns.format()}

Therefore, when the data is loaded, there should be {len(stock_name_list) + stock_prices.shape[1]} columns
""")
# Out:
# We expect an additional 197 columns when the query is done
#
# There are 3 columns with shape as (380, 3) in the base dataframe with column names as : ['date', 'biz_date', 'day']
#
# Therefore, when the data is loaded, there should be 200 columns

# %%
count = 1
error_tickers = []
for stock in stock_name_list:
    try:
        temp_stock_info_df = pd.DataFrame()

        print(f'Processing {stock}')
        print(f'Stock {count} of {len(stock_name_list)}')

        # temp_stock_info_df = (pd
        #                       .DataFrame(
        #                           pn.data.get(stock, base_start_date, base_end_date).loc[:,'Close'])
        #                       .rename({'Close':f'{stock}'},axis=1)
        #                      )
        
        temp_stock_info_df = (pd.DataFrame((web.DataReader(stock, 'yahoo', start=start_date, end=end_date)
                                               .loc[:,'Close']))
                                .rename({'Close':f'{stock}'},axis=1))

        print(f'Successfully processed {stock} at {datetime.today()}!')

        stock_prices = (stock_prices.merge(temp_stock_info_df, 
                                           how='left', 
                                           left_on='date', 
                                           right_on='Date'))

        print(f'DataFrame size is {stock_prices.shape}.\n')

        count += 1

        # Reduce RAM consumption
        del temp_stock_info_df
        gc.collect()
    
    except KeyError:
        error_tickers.append(stock)
        print(f'This ticker {stock} is not found.\n')
        continue
# Out:
# Processing AAP
# Stock 1 of 197
# Successfully processed AAP at 2022-01-17 21:31:47.615778!
# DataFrame size is (380, 4).
#
# Processing ABMD
# Stock 2 of 197
# Successfully processed ABMD at 2022-01-17 21:31:48.576256!
# DataFrame size is (380, 5).
#
# Processing ADP
# Stock 3 of 197
# Successfully processed ADP at 2022-01-17 21:31:49.555369!
# DataFrame size is (380, 6).
#
# Processing AEE
# Stock 4 of 197
# Successfully processed AEE at 2022-01-17 21:31:51.049876!
# DataFrame size is (380, 7).
#
# Processing AEP
# Stock 5 of 197
# Successfully processed AEP at 2022-01-17 21:31:52.109272!
# DataFrame size is (380, 8).
#
# Processing AES
# Stock 6 of 197
# Successfully processed AES at 2022-01-17 21:31:53.071469!
# DataFrame size is (380, 9).
#
# Processing AIG
# Stock 7 of 197
# Successfully processed AIG at 2022-01-17 21:31:54.003405!
# DataFrame size is (380, 10).
#
# Processing ALGN
# Stock 8 of 197
# Successfully processed ALGN at 2022-01-17 21:31:55.014319!
# DataFrame size is (380, 11).
#
# Processing ALLE
# Stock 9 of 197
# Successfully processed ALLE at 2022-01-17 21:31:56.024626!
# DataFrame size is (380, 12).
#
# Processing AMCR
# Stock 10 of 197
# Successfully processed AMCR at 2022-01-17 21:31:57.232968!
# DataFrame size is (380, 13).
#
# Processing AON
# Stock 11 of 197
# Successfully processed AON at 2022-01-17 21:31:58.223980!
# DataFrame size is (380, 14).
#
# Processing AOS
# Stock 12 of 197
# Successfully processed AOS at 2022-01-17 21:31:59.183556!
# DataFrame size is (380, 15).
#
# Processing ARE
# Stock 13 of 197
# Successfully processed ARE at 2022-01-17 21:31:59.804262!
# DataFrame size is (380, 16).
#
# Processing ATO
# Stock 14 of 197
# Successfully processed ATO at 2022-01-17 21:32:00.811143!
# DataFrame size is (380, 17).
#
# Processing AVGO
# Stock 15 of 197
# Successfully processed AVGO at 2022-01-17 21:32:01.535244!
# DataFrame size is (380, 18).
#
# Processing AVY
# Stock 16 of 197
# Successfully processed AVY at 2022-01-17 21:32:02.564819!
# DataFrame size is (380, 19).
#
# Processing AZO
# Stock 17 of 197
# Successfully processed AZO at 2022-01-17 21:32:03.551911!
# DataFrame size is (380, 20).
#
# Processing BA
# Stock 18 of 197
# Successfully processed BA at 2022-01-17 21:32:04.588129!
# DataFrame size is (380, 21).
#
# Processing BBWI
# Stock 19 of 197
# Successfully processed BBWI at 2022-01-17 21:32:05.620932!
# DataFrame size is (380, 22).
#
# Processing BKR
# Stock 20 of 197
# Successfully processed BKR at 2022-01-17 21:32:06.654476!
# DataFrame size is (380, 23).
#
# Processing BR
# Stock 21 of 197
# Successfully processed BR at 2022-01-17 21:32:07.736653!
# DataFrame size is (380, 24).
#
# Processing BRK-B
# Stock 22 of 197
# Successfully processed BRK-B at 2022-01-17 21:32:09.162606!
# DataFrame size is (380, 25).
#
# Processing BRO
# Stock 23 of 197
# Successfully processed BRO at 2022-01-17 21:32:10.120110!
# DataFrame size is (380, 26).
#
# Processing CARR
# Stock 24 of 197
# Successfully processed CARR at 2022-01-17 21:32:11.210041!
# DataFrame size is (380, 27).
#
# Processing CCI
# Stock 25 of 197
# Successfully processed CCI at 2022-01-17 21:32:12.092283!
# DataFrame size is (380, 28).
#
# Processing CCL
# Stock 26 of 197
# Successfully processed CCL at 2022-01-17 21:32:13.678660!
# DataFrame size is (380, 29).
#
# Processing CDAY
# Stock 27 of 197
# Successfully processed CDAY at 2022-01-17 21:32:14.822750!
# DataFrame size is (380, 30).
#
# Processing CDNS
# Stock 28 of 197
# Successfully processed CDNS at 2022-01-17 21:32:15.803409!
# DataFrame size is (380, 31).
#
# Processing CDW
# Stock 29 of 197
# Successfully processed CDW at 2022-01-17 21:32:17.295495!
# DataFrame size is (380, 32).
#
# Processing CE
# Stock 30 of 197
# Successfully processed CE at 2022-01-17 21:32:18.308566!
# DataFrame size is (380, 33).
#
# Processing CERN
# Stock 31 of 197
# Successfully processed CERN at 2022-01-17 21:32:19.264304!
# DataFrame size is (380, 34).
#
# Processing CFG
# Stock 32 of 197
# Successfully processed CFG at 2022-01-17 21:32:20.334991!
# DataFrame size is (380, 35).
#
# Processing CHD
# Stock 33 of 197
# Successfully processed CHD at 2022-01-17 21:32:21.332211!
# DataFrame size is (380, 36).
#
# Processing CHRW
# Stock 34 of 197
# Successfully processed CHRW at 2022-01-17 21:32:22.811801!
# DataFrame size is (380, 37).
#
# Processing CINF
# Stock 35 of 197
# Successfully processed CINF at 2022-01-17 21:32:23.799566!
# DataFrame size is (380, 38).
#
# Processing CLX
# Stock 36 of 197
# Successfully processed CLX at 2022-01-17 21:32:24.522218!
# DataFrame size is (380, 39).
#
# Processing CMG
# Stock 37 of 197
# Successfully processed CMG at 2022-01-17 21:32:25.534233!
# DataFrame size is (380, 40).
#
# Processing CMS
# Stock 38 of 197
# Successfully processed CMS at 2022-01-17 21:32:26.646303!
# DataFrame size is (380, 41).
#
# Processing CNC
# Stock 39 of 197
# Successfully processed CNC at 2022-01-17 21:32:27.754981!
# DataFrame size is (380, 42).
#
# Processing CNP
# Stock 40 of 197
# Successfully processed CNP at 2022-01-17 21:32:28.759525!
# DataFrame size is (380, 43).
#
# Processing COO
# Stock 41 of 197
# Successfully processed COO at 2022-01-17 21:32:29.801286!
# DataFrame size is (380, 44).
#
# Processing COST
# Stock 42 of 197
# Successfully processed COST at 2022-01-17 21:32:30.817226!
# DataFrame size is (380, 45).
#
# Processing CPRT
# Stock 43 of 197
# Successfully processed CPRT at 2022-01-17 21:32:32.209779!
# DataFrame size is (380, 46).
#
# Processing CRL
# Stock 44 of 197
# Successfully processed CRL at 2022-01-17 21:32:33.266493!
# DataFrame size is (380, 47).
#
# Processing CTLT
# Stock 45 of 197
# Successfully processed CTLT at 2022-01-17 21:32:34.070319!
# DataFrame size is (380, 48).
#
# Processing CTRA
# Stock 46 of 197
# Successfully processed CTRA at 2022-01-17 21:32:35.083892!
# DataFrame size is (380, 49).
#
# Processing CTSH
# Stock 47 of 197
# Successfully processed CTSH at 2022-01-17 21:32:36.192010!
# DataFrame size is (380, 50).
#
# Processing CTXS
# Stock 48 of 197
# Successfully processed CTXS at 2022-01-17 21:32:37.233405!
# DataFrame size is (380, 51).
#
# Processing CZR
# Stock 49 of 197
# Successfully processed CZR at 2022-01-17 21:32:37.871104!
# DataFrame size is (380, 52).
#
# Processing D
# Stock 50 of 197
# Successfully processed D at 2022-01-17 21:32:38.876699!
# DataFrame size is (380, 53).
#
# Processing DD
# Stock 51 of 197
# Successfully processed DD at 2022-01-17 21:32:39.901426!
# DataFrame size is (380, 54).
#
# Processing DG
# Stock 52 of 197
# Successfully processed DG at 2022-01-17 21:32:40.849953!
# DataFrame size is (380, 55).
#
# Processing DHI
# Stock 53 of 197
# Successfully processed DHI at 2022-01-17 21:32:41.865619!
# DataFrame size is (380, 56).
#
# Processing DISH
# Stock 54 of 197
# Successfully processed DISH at 2022-01-17 21:32:43.007083!
# DataFrame size is (380, 57).
#
# Processing DPZ
# Stock 55 of 197
# Successfully processed DPZ at 2022-01-17 21:32:44.026232!
# DataFrame size is (380, 58).
#
# Processing DRI
# Stock 56 of 197
# Successfully processed DRI at 2022-01-17 21:32:45.023543!
# DataFrame size is (380, 59).
#
# Processing DTE
# Stock 57 of 197
# Successfully processed DTE at 2022-01-17 21:32:46.118413!
# DataFrame size is (380, 60).
#
# Processing DUK
# Stock 58 of 197
# Successfully processed DUK at 2022-01-17 21:32:47.103532!
# DataFrame size is (380, 61).
#
# Processing DXCM
# Stock 59 of 197
# Successfully processed DXCM at 2022-01-17 21:32:48.332688!
# DataFrame size is (380, 62).
#
# Processing EFX
# Stock 60 of 197
# Successfully processed EFX at 2022-01-17 21:32:49.337335!
# DataFrame size is (380, 63).
#
# Processing EL
# Stock 61 of 197
# Successfully processed EL at 2022-01-17 21:32:50.317867!
# DataFrame size is (380, 64).
#
# Processing ENPH
# Stock 62 of 197
# Successfully processed ENPH at 2022-01-17 21:32:51.371036!
# DataFrame size is (380, 65).
#
# Processing EOG
# Stock 63 of 197
# Successfully processed EOG at 2022-01-17 21:32:52.442624!
# DataFrame size is (380, 66).
#
# Processing EPAM
# Stock 64 of 197
# Successfully processed EPAM at 2022-01-17 21:32:53.427028!
# DataFrame size is (380, 67).
#
# Processing EVRG
# Stock 65 of 197
# Successfully processed EVRG at 2022-01-17 21:32:54.427248!
# DataFrame size is (380, 68).
#
# Processing EXPD
# Stock 66 of 197
# Successfully processed EXPD at 2022-01-17 21:32:55.459484!
# DataFrame size is (380, 69).
#
# Processing EXPE
# Stock 67 of 197
# Successfully processed EXPE at 2022-01-17 21:32:56.290382!
# DataFrame size is (380, 70).
#
# Processing FANG
# Stock 68 of 197
# Successfully processed FANG at 2022-01-17 21:32:57.407984!
# DataFrame size is (380, 71).
#
# Processing FB
# Stock 69 of 197
# Successfully processed FB at 2022-01-17 21:32:58.347172!
# DataFrame size is (380, 72).
#
# Processing FBHS
# Stock 70 of 197
# Successfully processed FBHS at 2022-01-17 21:32:59.697343!
# DataFrame size is (380, 73).
#
# Processing FDS
# Stock 71 of 197
# Successfully processed FDS at 2022-01-17 21:33:00.682119!
# DataFrame size is (380, 74).
#
# Processing FFIV
# Stock 72 of 197
# Successfully processed FFIV at 2022-01-17 21:33:02.288073!
# DataFrame size is (380, 75).
#
# Processing FIS
# Stock 73 of 197
# Successfully processed FIS at 2022-01-17 21:33:03.256545!
# DataFrame size is (380, 76).
#
# Processing FISV
# Stock 74 of 197
# Successfully processed FISV at 2022-01-17 21:33:04.425735!
# DataFrame size is (380, 77).
#
# Processing FLT
# Stock 75 of 197
# Successfully processed FLT at 2022-01-17 21:33:05.394637!
# DataFrame size is (380, 78).
#
# Processing FOX
# Stock 76 of 197
# Successfully processed FOX at 2022-01-17 21:33:06.152609!
# DataFrame size is (380, 79).
#
# Processing FOXA
# Stock 77 of 197
# Successfully processed FOXA at 2022-01-17 21:33:07.154962!
# DataFrame size is (380, 80).
#
# Processing FRC
# Stock 78 of 197
# Successfully processed FRC at 2022-01-17 21:33:08.237041!
# DataFrame size is (380, 81).
#
# Processing FRT
# Stock 79 of 197
# Successfully processed FRT at 2022-01-17 21:33:09.300244!
# DataFrame size is (380, 82).
#
# Processing FTNT
# Stock 80 of 197
# Successfully processed FTNT at 2022-01-17 21:33:10.314602!
# DataFrame size is (380, 83).
#
# Processing GD
# Stock 81 of 197
# Successfully processed GD at 2022-01-17 21:33:11.382757!
# DataFrame size is (380, 84).
#
# Processing GNRC
# Stock 82 of 197
# Successfully processed GNRC at 2022-01-17 21:33:12.523688!
# DataFrame size is (380, 85).
#
# Processing GPC
# Stock 83 of 197
# Successfully processed GPC at 2022-01-17 21:33:13.605265!
# DataFrame size is (380, 86).
#
# Processing GPN
# Stock 84 of 197
# Successfully processed GPN at 2022-01-17 21:33:15.251495!
# DataFrame size is (380, 87).
#
# Processing GRMN
# Stock 85 of 197
# Successfully processed GRMN at 2022-01-17 21:33:16.524276!
# DataFrame size is (380, 88).
#
# Processing HBAN
# Stock 86 of 197
# Successfully processed HBAN at 2022-01-17 21:33:17.537292!
# DataFrame size is (380, 89).
#
# Processing HCA
# Stock 87 of 197
# Successfully processed HCA at 2022-01-17 21:33:18.607936!
# DataFrame size is (380, 90).
#
# Processing HII
# Stock 88 of 197
# Successfully processed HII at 2022-01-17 21:33:19.574242!
# DataFrame size is (380, 91).
#
# Processing HON
# Stock 89 of 197
# Successfully processed HON at 2022-01-17 21:33:20.541433!
# DataFrame size is (380, 92).
#
# Processing IBM
# Stock 90 of 197
# Successfully processed IBM at 2022-01-17 21:33:21.586006!
# DataFrame size is (380, 93).
#
# Processing IPGP
# Stock 91 of 197
# Successfully processed IPGP at 2022-01-17 21:33:22.676726!
# DataFrame size is (380, 94).
#
# Processing IQV
# Stock 92 of 197
# Successfully processed IQV at 2022-01-17 21:33:23.616560!
# DataFrame size is (380, 95).
#
# Processing ISRG
# Stock 93 of 197
# Successfully processed ISRG at 2022-01-17 21:33:24.615067!
# DataFrame size is (380, 96).
#
# Processing IT
# Stock 94 of 197
# Successfully processed IT at 2022-01-17 21:33:25.634056!
# DataFrame size is (380, 97).
#
# Processing J
# Stock 95 of 197
# Successfully processed J at 2022-01-17 21:33:26.948322!
# DataFrame size is (380, 98).
#
# Processing JBHT
# Stock 96 of 197
# Successfully processed JBHT at 2022-01-17 21:33:28.018209!
# DataFrame size is (380, 99).
#
# Processing JKHY
# Stock 97 of 197
# Successfully processed JKHY at 2022-01-17 21:33:29.129959!
# DataFrame size is (380, 100).
#
# Processing JNJ
# Stock 98 of 197
# Successfully processed JNJ at 2022-01-17 21:33:30.107206!
# DataFrame size is (380, 101).
#
# Processing KMB
# Stock 99 of 197
# Successfully processed KMB at 2022-01-17 21:33:31.193968!
# DataFrame size is (380, 102).
#
# Processing L
# Stock 100 of 197
# Successfully processed L at 2022-01-17 21:33:32.141721!
# DataFrame size is (380, 103).
#
# Processing LEN
# Stock 101 of 197
# Successfully processed LEN at 2022-01-17 21:33:33.083762!
# DataFrame size is (380, 104).
#
# Processing LKQ
# Stock 102 of 197
# Successfully processed LKQ at 2022-01-17 21:33:34.426680!
# DataFrame size is (380, 105).
#
# Processing LMT
# Stock 103 of 197
# Successfully processed LMT at 2022-01-17 21:33:35.447797!
# DataFrame size is (380, 106).
#
# Processing LNT
# Stock 104 of 197
# Successfully processed LNT at 2022-01-17 21:33:36.493535!
# DataFrame size is (380, 107).
#
# Processing LUMN
# Stock 105 of 197
# Successfully processed LUMN at 2022-01-17 21:33:37.472742!
# DataFrame size is (380, 108).
#
# Processing LUV
# Stock 106 of 197
# Successfully processed LUV at 2022-01-17 21:33:38.431326!
# DataFrame size is (380, 109).
#
# Processing LW
# Stock 107 of 197
# Successfully processed LW at 2022-01-17 21:33:39.444572!
# DataFrame size is (380, 110).
#
# Processing MAA
# Stock 108 of 197
# Successfully processed MAA at 2022-01-17 21:33:40.501507!
# DataFrame size is (380, 111).
#
# Processing MAS
# Stock 109 of 197
# Successfully processed MAS at 2022-01-17 21:33:41.509212!
# DataFrame size is (380, 112).
#
# Processing MCHP
# Stock 110 of 197
# Successfully processed MCHP at 2022-01-17 21:33:42.611806!
# DataFrame size is (380, 113).
#
# Processing MHK
# Stock 111 of 197
# Successfully processed MHK at 2022-01-17 21:33:44.480304!
# DataFrame size is (380, 114).
#
# Processing MMM
# Stock 112 of 197
# Successfully processed MMM at 2022-01-17 21:33:45.533722!
# DataFrame size is (380, 115).
#
# Processing MNST
# Stock 113 of 197
# Successfully processed MNST at 2022-01-17 21:33:46.550892!
# DataFrame size is (380, 116).
#
# Processing MO
# Stock 114 of 197
# Successfully processed MO at 2022-01-17 21:33:47.512292!
# DataFrame size is (380, 117).
#
# Processing MPWR
# Stock 115 of 197
# Successfully processed MPWR at 2022-01-17 21:33:48.694941!
# DataFrame size is (380, 118).
#
# Processing MRNA
# Stock 116 of 197
# Successfully processed MRNA at 2022-01-17 21:33:50.588958!
# DataFrame size is (380, 119).
#
# Processing MRO
# Stock 117 of 197
# Successfully processed MRO at 2022-01-17 21:33:52.153497!
# DataFrame size is (380, 120).
#
# Processing MTB
# Stock 118 of 197
# Successfully processed MTB at 2022-01-17 21:33:53.201629!
# DataFrame size is (380, 121).
#
# Processing MTCH
# Stock 119 of 197
# Successfully processed MTCH at 2022-01-17 21:33:54.298677!
# DataFrame size is (380, 122).
#
# Processing NCLH
# Stock 120 of 197
# Successfully processed NCLH at 2022-01-17 21:33:55.258848!
# DataFrame size is (380, 123).
#
# Processing NFLX
# Stock 121 of 197
# Successfully processed NFLX at 2022-01-17 21:33:56.203739!
# DataFrame size is (380, 124).
#
# Processing NI
# Stock 122 of 197
# Successfully processed NI at 2022-01-17 21:33:57.190592!
# DataFrame size is (380, 125).
#
# Processing NOC
# Stock 123 of 197
# Successfully processed NOC at 2022-01-17 21:33:58.209385!
# DataFrame size is (380, 126).
#
# Processing NOW
# Stock 124 of 197
# Successfully processed NOW at 2022-01-17 21:33:59.210716!
# DataFrame size is (380, 127).
#
# Processing NRG
# Stock 125 of 197
# Successfully processed NRG at 2022-01-17 21:34:00.302514!
# DataFrame size is (380, 128).
#
# Processing NTAP
# Stock 126 of 197
# Successfully processed NTAP at 2022-01-17 21:34:01.350250!
# DataFrame size is (380, 129).
#
# Processing NUE
# Stock 127 of 197
# Successfully processed NUE at 2022-01-17 21:34:02.324240!
# DataFrame size is (380, 130).
#
# Processing NVR
# Stock 128 of 197
# Successfully processed NVR at 2022-01-17 21:34:03.360304!
# DataFrame size is (380, 131).
#
# Processing NXPI
# Stock 129 of 197
# Successfully processed NXPI at 2022-01-17 21:34:04.843986!
# DataFrame size is (380, 132).
#
# Processing ODFL
# Stock 130 of 197
# Successfully processed ODFL at 2022-01-17 21:34:05.875959!
# DataFrame size is (380, 133).
#
# Processing OGN
# Stock 131 of 197
# Successfully processed OGN at 2022-01-17 21:34:06.868910!
# DataFrame size is (380, 134).
#
# Processing ORLY
# Stock 132 of 197
# Successfully processed ORLY at 2022-01-17 21:34:07.927566!
# DataFrame size is (380, 135).
#
# Processing OTIS
# Stock 133 of 197
# Successfully processed OTIS at 2022-01-17 21:34:09.025342!
# DataFrame size is (380, 136).
#
# Processing PAYC
# Stock 134 of 197
# Successfully processed PAYC at 2022-01-17 21:34:10.084573!
# DataFrame size is (380, 137).
#
# Processing PAYX
# Stock 135 of 197
# Successfully processed PAYX at 2022-01-17 21:34:10.876371!
# DataFrame size is (380, 138).
#
# Processing PBCT
# Stock 136 of 197
# Successfully processed PBCT at 2022-01-17 21:34:11.718533!
# DataFrame size is (380, 139).
#
# Processing PENN
# Stock 137 of 197
# Successfully processed PENN at 2022-01-17 21:34:13.068323!
# DataFrame size is (380, 140).
#
# Processing PKG
# Stock 138 of 197
# Successfully processed PKG at 2022-01-17 21:34:14.147671!
# DataFrame size is (380, 141).
#
# Processing PM
# Stock 139 of 197
# Successfully processed PM at 2022-01-17 21:34:15.339098!
# DataFrame size is (380, 142).
#
# Processing PNW
# Stock 140 of 197
# Successfully processed PNW at 2022-01-17 21:34:16.933081!
# DataFrame size is (380, 143).
#
# Processing POOL
# Stock 141 of 197
# Successfully processed POOL at 2022-01-17 21:34:17.917293!
# DataFrame size is (380, 144).
#
# Processing PPL
# Stock 142 of 197
# Successfully processed PPL at 2022-01-17 21:34:18.893805!
# DataFrame size is (380, 145).
#
# Processing PSA
# Stock 143 of 197
# Successfully processed PSA at 2022-01-17 21:34:19.927019!
# DataFrame size is (380, 146).
#
# Processing PSX
# Stock 144 of 197
# Successfully processed PSX at 2022-01-17 21:34:20.931713!
# DataFrame size is (380, 147).
#
# Processing PTC
# Stock 145 of 197
# Successfully processed PTC at 2022-01-17 21:34:21.928526!
# DataFrame size is (380, 148).
#
# Processing PWR
# Stock 146 of 197
# Successfully processed PWR at 2022-01-17 21:34:22.915468!
# DataFrame size is (380, 149).
#
# Processing PYPL
# Stock 147 of 197
# Successfully processed PYPL at 2022-01-17 21:34:24.258059!
# DataFrame size is (380, 150).
#
# Processing QRVO
# Stock 148 of 197
# Successfully processed QRVO at 2022-01-17 21:34:25.378762!
# DataFrame size is (380, 151).
#
# Processing RE
# Stock 149 of 197
# Successfully processed RE at 2022-01-17 21:34:26.408773!
# DataFrame size is (380, 152).
#
# Processing RMD
# Stock 150 of 197
# Successfully processed RMD at 2022-01-17 21:34:27.452662!
# DataFrame size is (380, 153).
#
# Processing ROL
# Stock 151 of 197
# Successfully processed ROL at 2022-01-17 21:34:28.498105!
# DataFrame size is (380, 154).
#
# Processing ROST
# Stock 152 of 197
# Successfully processed ROST at 2022-01-17 21:34:29.495236!
# DataFrame size is (380, 155).
#
# Processing RTX
# Stock 153 of 197
# Successfully processed RTX at 2022-01-17 21:34:30.412825!
# DataFrame size is (380, 156).
#
# Processing SBAC
# Stock 154 of 197
# Successfully processed SBAC at 2022-01-17 21:34:31.431908!
# DataFrame size is (380, 157).
#
# Processing SBNY
# Stock 155 of 197
# Successfully processed SBNY at 2022-01-17 21:34:32.923578!
# DataFrame size is (380, 158).
#
# Processing SEDG
# Stock 156 of 197
# Successfully processed SEDG at 2022-01-17 21:34:33.860609!
# DataFrame size is (380, 159).
#
# Processing SEE
# Stock 157 of 197
# Successfully processed SEE at 2022-01-17 21:34:34.912528!
# DataFrame size is (380, 160).
#
# Processing SHW
# Stock 158 of 197
# Successfully processed SHW at 2022-01-17 21:34:35.959613!
# DataFrame size is (380, 161).
#
# Processing SIVB
# Stock 159 of 197
# Successfully processed SIVB at 2022-01-17 21:34:36.953229!
# DataFrame size is (380, 162).
#
# Processing SNPS
# Stock 160 of 197
# Successfully processed SNPS at 2022-01-17 21:34:38.005445!
# DataFrame size is (380, 163).
#
# Processing SO
# Stock 161 of 197
# Successfully processed SO at 2022-01-17 21:34:38.942672!
# DataFrame size is (380, 164).
#
# Processing SPY
# Stock 162 of 197
# Successfully processed SPY at 2022-01-17 21:34:40.104694!
# DataFrame size is (380, 165).
#
# Processing STE
# Stock 163 of 197
# Successfully processed STE at 2022-01-17 21:34:41.269526!
# DataFrame size is (380, 166).
#
# Processing SWKS
# Stock 164 of 197
# Successfully processed SWKS at 2022-01-17 21:34:42.287561!
# DataFrame size is (380, 167).
#
# Processing SYK
# Stock 165 of 197
# Successfully processed SYK at 2022-01-17 21:34:43.467186!
# DataFrame size is (380, 168).
#
# Processing TDY
# Stock 166 of 197
# Successfully processed TDY at 2022-01-17 21:34:44.418317!
# DataFrame size is (380, 169).
#
# Processing TECH
# Stock 167 of 197
# Successfully processed TECH at 2022-01-17 21:34:45.402363!
# DataFrame size is (380, 170).
#
# Processing TER
# Stock 168 of 197
# Successfully processed TER at 2022-01-17 21:34:46.369960!
# DataFrame size is (380, 171).
#
# Processing TFC
# Stock 169 of 197
# Successfully processed TFC at 2022-01-17 21:34:47.321807!
# DataFrame size is (380, 172).
#
# Processing TFX
# Stock 170 of 197
# Successfully processed TFX at 2022-01-17 21:34:48.313334!
# DataFrame size is (380, 173).
#
# Processing TMUS
# Stock 171 of 197
# Successfully processed TMUS at 2022-01-17 21:34:49.997941!
# DataFrame size is (380, 174).
#
# Processing TSCO
# Stock 172 of 197
# Successfully processed TSCO at 2022-01-17 21:34:50.993204!
# DataFrame size is (380, 175).
#
# Processing TWTR
# Stock 173 of 197
# Successfully processed TWTR at 2022-01-17 21:34:52.027899!
# DataFrame size is (380, 176).
#
# Processing TXT
# Stock 174 of 197
# Successfully processed TXT at 2022-01-17 21:34:53.394320!
# DataFrame size is (380, 177).
#
# Processing TYL
# Stock 175 of 197
# Successfully processed TYL at 2022-01-17 21:34:54.386321!
# DataFrame size is (380, 178).
#
# Processing UAL
# Stock 176 of 197
# Successfully processed UAL at 2022-01-17 21:34:55.388578!
# DataFrame size is (380, 179).
#
# Processing UDR
# Stock 177 of 197
# Successfully processed UDR at 2022-01-17 21:34:56.208462!
# DataFrame size is (380, 180).
#
# Processing UHS
# Stock 178 of 197
# Successfully processed UHS at 2022-01-17 21:34:57.315183!
# DataFrame size is (380, 181).
#
# Processing ULTA
# Stock 179 of 197
# Successfully processed ULTA at 2022-01-17 21:34:58.280597!
# DataFrame size is (380, 182).
#
# Processing USB
# Stock 180 of 197
# Successfully processed USB at 2022-01-17 21:34:59.630054!
# DataFrame size is (380, 183).
#
# Processing VIAC
# Stock 181 of 197
# Successfully processed VIAC at 2022-01-17 21:35:00.634238!
# DataFrame size is (380, 184).
#
# Processing VLO
# Stock 182 of 197
# Successfully processed VLO at 2022-01-17 21:35:01.513112!
# DataFrame size is (380, 185).
#
# Processing VMC
# Stock 183 of 197
# Successfully processed VMC at 2022-01-17 21:35:02.500102!
# DataFrame size is (380, 186).
#
# Processing VRSN
# Stock 184 of 197
# Successfully processed VRSN at 2022-01-17 21:35:03.516505!
# DataFrame size is (380, 187).
#
# Processing WDC
# Stock 185 of 197
# Successfully processed WDC at 2022-01-17 21:35:04.488685!
# DataFrame size is (380, 188).
#
# Processing WEC
# Stock 186 of 197
# Successfully processed WEC at 2022-01-17 21:35:05.620422!
# DataFrame size is (380, 189).
#
# Processing WFC
# Stock 187 of 197
# Successfully processed WFC at 2022-01-17 21:35:06.699305!
# DataFrame size is (380, 190).
#
# Processing WRB
# Stock 188 of 197
# Successfully processed WRB at 2022-01-17 21:35:08.127395!
# DataFrame size is (380, 191).
#
# Processing WTW
# Stock 189 of 197
# Successfully processed WTW at 2022-01-17 21:35:09.232419!
# DataFrame size is (380, 192).
#
# Processing WYNN
# Stock 190 of 197
# Successfully processed WYNN at 2022-01-17 21:35:10.369359!
# DataFrame size is (380, 193).
#
# Processing XEL
# Stock 191 of 197
# Successfully processed XEL at 2022-01-17 21:35:11.534077!
# DataFrame size is (380, 194).
#
# Processing XLNX
# Stock 192 of 197
# Successfully processed XLNX at 2022-01-17 21:35:12.529197!
# DataFrame size is (380, 195).
#
# Processing XRAY
# Stock 193 of 197
# Successfully processed XRAY at 2022-01-17 21:35:13.651527!
# DataFrame size is (380, 196).
#
# Processing ZBH
# Stock 194 of 197
# Successfully processed ZBH at 2022-01-17 21:35:14.653638!
# DataFrame size is (380, 197).
#
# Processing ZION
# Stock 195 of 197
# Successfully processed ZION at 2022-01-17 21:35:15.654951!
# DataFrame size is (380, 198).
#
# Processing ZTS
# Stock 196 of 197
# Successfully processed ZTS at 2022-01-17 21:35:16.635776!
# DataFrame size is (380, 199).
#
# Processing SNPE
# Stock 197 of 197
# Successfully processed SNPE at 2022-01-17 21:35:17.612841!
# DataFrame size is (380, 200).

# %%
stock_prices.head()
# Out:
#         date   biz_date  day         AAP        ABMD         ADP        AEE  \
# 0 2020-12-31 2020-12-31    3  157.509995  324.200012  176.199997  78.059998
# 1 2021-01-01 2021-01-01    4         NaN         NaN         NaN        NaN
# 2 2021-01-02        NaT    5         NaN         NaN         NaN        NaN
# 3 2021-01-03        NaT    6         NaN         NaN         NaN        NaN
# 4 2021-01-04 2021-01-04    0  157.339996  316.730011  168.960007  76.129997
#
#          AEP    AES        AIG  ...        WRB         WTW        WYNN  \
# 0  83.269997  23.50  37.860001  ...  66.419998  210.679993  112.830002
# 1        NaN    NaN        NaN  ...        NaN         NaN         NaN
# 2        NaN    NaN        NaN  ...        NaN         NaN         NaN
# 3        NaN    NaN        NaN  ...        NaN         NaN         NaN
# 4  81.540001  23.24  37.130001  ...  64.940002  203.699997  106.900002
#
#          XEL        XLNX       XRAY         ZBH       ZION         ZTS  \
# 0  66.669998  141.770004  52.360001  154.089996  43.439999  165.500000
# 1        NaN         NaN        NaN         NaN        NaN         NaN
# 2        NaN         NaN        NaN         NaN        NaN         NaN
# 3        NaN         NaN        NaN         NaN        NaN         NaN
# 4  65.660004  142.429993  53.750000  153.160004  42.930000  163.589996
#
#         SNPE
# 0  32.840000
# 1        NaN
# 2        NaN
# 3        NaN
# 4  32.369999
#
# [5 rows x 200 columns]

# %%
stock_prices_long = pd.melt(stock_prices, 
                            id_vars=['date', 'biz_date', 'day'],
                            value_vars=stock_prices.columns[3:],
                            var_name='ticker',
                            value_name='price')

# %%
stock_prices_long
# Out:
#             date   biz_date  day ticker       price
# 0     2020-12-31 2020-12-31    3    AAP  157.509995
# 1     2021-01-01 2021-01-01    4    AAP         NaN
# 2     2021-01-02        NaT    5    AAP         NaN
# 3     2021-01-03        NaT    6    AAP         NaN
# 4     2021-01-04 2021-01-04    0    AAP  157.339996
# ...          ...        ...  ...    ...         ...
# 74855 2022-01-10 2022-01-10    0   SNPE   41.810001
# 74856 2022-01-11 2022-01-11    1   SNPE   42.200001
# 74857 2022-01-12 2022-01-12    2   SNPE   42.349998
# 74858 2022-01-13 2022-01-13    3   SNPE   41.730000
# 74859 2022-01-14 2022-01-14    4   SNPE   41.759998
#
# [74860 rows x 5 columns]

# %%
stock_prices.to_csv(f"{transform_path}/non_esg_stock_prices_wide_{datetime.now().date()}.csv",index=False)
stock_prices_long.to_csv(f"{transform_path}/non_esg_stock_prices_long_{datetime.now().date()}.csv",index=False)

# %%
print(error_tickers)
# Out:
# []
